# %% [markdown]
# Step 1 :
#
# I start by importing the libraries that I need to analyze and visualize the weather across the world at a varying distance from the equator.

# %%
#import dependencies

import json
import requests

import numpy as np
import pandas as pd
import random 

import matplotlib.pyplot as plt
import seaborn as sns

from config import api_key
from citipy import citipy
from datetime import date

# %% [markdown]
# Step 2:
#
# I create an empty dataframe with required columns to hold the values extracted from APIs from https://openweathermap.org/api.
#
# Columns - "City","Country","Latitude","Temperature","Humidity","Cloudiness","Wind Speed".

# %%
# Define columns and Dataframe - "City","Country_Code","Latitude","Longitude"

columns =["City","Country_Code","Latitude","Longitude"]
          

Weather_Summary = pd.DataFrame(columns=columns)

# %% [markdown]
# Step 3:
#
# I define a function to generate uniform and random sets of latitude and longitude.

# %%
#Define function to assign random coordinates across the world, and return them when called

def lat_lon():
    lon = np.random.uniform(-180,180)
    lat = np.random.uniform(-90, 90)
    return(lat,lon)

# List comprehension to generate generate uniform and random sets of latitude and longitude

Coordinates = [lat_lon() for point in range(5000)]

# %% [markdown]
# Step 4:
#
# I use citipy library to pass the coordinates collected above and get the corresponding cities and country codes. I define the
#
# list of cities(Weather_Summary_Cities) randomly selected from the superset Weather_Summary.

# %%
# Define empty list to hold a row to write to the the dataframe

Weather_Summary_Dict = []

# Loop through coordinates, get the city name and country codes, and append to empty list defined above

for coordinate_pair in Coordinates:
    lat,lon = coordinate_pair
    City = citipy.nearest_city(lat, lon)
    Weather_Summary_Dict.append({"City": City.city_name,
                                 "Country_Code":City.country_code,
                                 "Latitude" : lat,
                                 "Longitude" : lon})

# Append the entire set of records to the dataframe; Cleaning the data to drop duplicates 

Weather_Summary = Weather_Summary.append(Weather_Summary_Dict)

Weather_Summary_Duplicates_Removed = Weather_Summary.drop_duplicates(subset=["City","Country_Code"],keep=False)


# Random selection of cities from Weather_Summary_Cities; Weather_Summary_Cities has 800 records to handle the scenario 
# that some cities may not have information retrieved from the API

Weather_Summary_Cities = Weather_Summary_Duplicates_Removed.sample(n=800)

# %% [markdown]
# Step 5:
#
# I define the base url -api.openweathermap.org/data/2.5/weather?q={city name},{country code} and pass city, country code to
#
# collect the attributes : "Temperature","Humidity","Cloudiness","Wind Speed". The objective is to perform a weather check on each
#
# city over the entire list using a series of successive API calls.

# %%
    # Extend the data frame to hold the new columns

    Weather_Summary_Cities["Max_Temperature"] = ""
    Weather_Summary_Cities["Humidity"] = ""
    Weather_Summary_Cities["Cloudiness"] = ""
    Weather_Summary_Cities["Wind_Speed"] = ""


    # Define base url 

    base_url = "http://api.openweathermap.org/data/2.5/find?q="

    # Define units=imperial, for temperature in Fahrenheit and Wind Speed in miles per hour
    # Source: https://openweathermap.org/weather-data

    units = "imperial"
    Records_Found = 0 

    # use iterrows to iterate through pandas dataframe
    
    for index, row in Weather_Summary_Cities.iterrows():
        
        # For better readability of the print log, the city has been translated to upper case
        
        City_Identifier = row["City"].upper()
        
        # Condition to stop the processing when 500 unique cities have been collected        
        
        if Records_Found < 500:
            
            #  Condition to check spaces in city value, and insert %20 in the api response          
            
            if " " in row["City"]:  
                City_Mod = "%20".join(row["City"].split(" "))
                url = base_url + City_Mod + "," + row["Country_Code"] + "&units=" + units +"&appid=" + api_key
                response = requests.get(url).json()
            else:
                url = base_url + row["City"] + "," + row["Country_Code"] + "&units=" + units +"&appid=" + api_key
                response = requests.get(url).json()       
            
            #  Writing the weather details to the dataframe
            
            try:
                Weather_Summary_Cities.loc[index,"Max_Temperature"] = response["list"][0]["main"]["temp_max"]
                Weather_Summary_Cities.loc[index,"Humidity"] = response["list"][0]["main"]["humidity"]
                Weather_Summary_Cities.loc[index,"Cloudiness"] = response["list"][0]["clouds"]["all"]
                Weather_Summary_Cities.loc[index,"Wind_Speed"] = response["list"][0]["wind"]["speed"]
                Records_Found = Records_Found + 1

                # Include a print log of each city and corresponding API endpoint

                print(f"Processing Record {Records_Found} | {City_Identifier}")
                print(url)       
            
            #  Indicate the records where no records were found    
            
            except:
                print("No results for city " + row["City"] + " found!")
                continue     
                
    # Determines successful processing and collection of weather details for 500 unique cities
    
    print(f"{Records_Found} unique cities are ready for further analysis!")
# Out:
# Processing Record 1 | GOLDEN
# http://api.openweathermap.org/data/2.5/find?q=golden,ca&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 2 | TEYA
# http://api.openweathermap.org/data/2.5/find?q=teya,ru&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 3 | MAREEBA
# http://api.openweathermap.org/data/2.5/find?q=mareeba,au&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 4 | SPRING HILL
# http://api.openweathermap.org/data/2.5/find?q=spring%20hill,us&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 5 | ADJUMANI
# http://api.openweathermap.org/data/2.5/find?q=adjumani,ug&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 6 | HOBYO
# http://api.openweathermap.org/data/2.5/find?q=hobyo,so&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 7 | BATAGAY
# http://api.openweathermap.org/data/2.5/find?q=batagay,ru&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 8 | ONDANGWA
# http://api.openweathermap.org/data/2.5/find?q=ondangwa,na&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 9 | KOLHAPUR
# http://api.openweathermap.org/data/2.5/find?q=kolhapur,in&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 10 | KAJAANI
# http://api.openweathermap.org/data/2.5/find?q=kajaani,fi&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 11 | BAMBANGLIPURO
# http://api.openweathermap.org/data/2.5/find?q=bambanglipuro,id&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 12 | BODAYBO
# http://api.openweathermap.org/data/2.5/find?q=bodaybo,ru&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 13 | WILLIAMSBURG
# http://api.openweathermap.org/data/2.5/find?q=williamsburg,us&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# No results for city krasnoarmeysk found!
# Processing Record 14 | ABIRAMAM
# http://api.openweathermap.org/data/2.5/find?q=abiramam,in&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# No results for city labutta found!
# Processing Record 15 | KOLONDIEBA
# http://api.openweathermap.org/data/2.5/find?q=kolondieba,ml&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 16 | LINJIANG
# http://api.openweathermap.org/data/2.5/find?q=linjiang,cn&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 17 | BOA VISTA
# http://api.openweathermap.org/data/2.5/find?q=boa%20vista,br&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 18 | ZNAMENSKOYE
# http://api.openweathermap.org/data/2.5/find?q=znamenskoye,ru&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 19 | TILICHIKI
# http://api.openweathermap.org/data/2.5/find?q=tilichiki,ru&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 20 | KINDERSLEY
# http://api.openweathermap.org/data/2.5/find?q=kindersley,ca&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# No results for city bobo dioulasso found!
# Processing Record 21 | ZURRIEQ
# http://api.openweathermap.org/data/2.5/find?q=zurrieq,mt&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 22 | WAU
# http://api.openweathermap.org/data/2.5/find?q=wau,pg&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 23 | BAUCHI
# http://api.openweathermap.org/data/2.5/find?q=bauchi,ng&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 24 | PINGLIANG
# http://api.openweathermap.org/data/2.5/find?q=pingliang,cn&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 25 | ROSETTA
# http://api.openweathermap.org/data/2.5/find?q=rosetta,eg&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# No results for city borama found!
# Processing Record 26 | ARMAN
# http://api.openweathermap.org/data/2.5/find?q=arman,ru&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 27 | MANZANILLO
# http://api.openweathermap.org/data/2.5/find?q=manzanillo,mx&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 28 | KRASYLIV
# http://api.openweathermap.org/data/2.5/find?q=krasyliv,ua&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 29 | SISIMIUT
# http://api.openweathermap.org/data/2.5/find?q=sisimiut,gl&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 30 | BOZOUM
# http://api.openweathermap.org/data/2.5/find?q=bozoum,cf&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 31 | PUERTO ARMUELLES
# http://api.openweathermap.org/data/2.5/find?q=puerto%20armuelles,pa&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 32 | WONTHAGGI
# http://api.openweathermap.org/data/2.5/find?q=wonthaggi,au&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 33 | MUYEZERSKIY
# http://api.openweathermap.org/data/2.5/find?q=muyezerskiy,ru&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 34 | TONGLIAO
# http://api.openweathermap.org/data/2.5/find?q=tongliao,cn&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 35 | POP
# http://api.openweathermap.org/data/2.5/find?q=pop,uz&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 36 | KARAGACH
# http://api.openweathermap.org/data/2.5/find?q=karagach,ru&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 37 | BASTIA
# http://api.openweathermap.org/data/2.5/find?q=bastia,fr&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 38 | COOLUM BEACH
# http://api.openweathermap.org/data/2.5/find?q=coolum%20beach,au&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 39 | SAINT-LEU
# http://api.openweathermap.org/data/2.5/find?q=saint-leu,re&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 40 | PAWAI
# http://api.openweathermap.org/data/2.5/find?q=pawai,in&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 41 | NYAGAN
# http://api.openweathermap.org/data/2.5/find?q=nyagan,ru&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 42 | PORTO VELHO
# http://api.openweathermap.org/data/2.5/find?q=porto%20velho,br&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 43 | YEROFEY PAVLOVICH
# http://api.openweathermap.org/data/2.5/find?q=yerofey%20pavlovich,ru&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# No results for city yingzhong found!
# No results for city bacuit found!
# Processing Record 44 | HANZHONG
# http://api.openweathermap.org/data/2.5/find?q=hanzhong,cn&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 45 | LINQIONG
# http://api.openweathermap.org/data/2.5/find?q=linqiong,cn&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 46 | TEGUISE
# http://api.openweathermap.org/data/2.5/find?q=teguise,es&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 47 | LUFILUFI
# http://api.openweathermap.org/data/2.5/find?q=lufilufi,ws&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 48 | POUM
# http://api.openweathermap.org/data/2.5/find?q=poum,nc&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 49 | JINCHANG
# http://api.openweathermap.org/data/2.5/find?q=jinchang,cn&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 50 | SAN POLICARPO
# http://api.openweathermap.org/data/2.5/find?q=san%20policarpo,ph&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# No results for city solsvik found!
# Processing Record 51 | HARIHAR
# http://api.openweathermap.org/data/2.5/find?q=harihar,in&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 52 | LAMPA
# http://api.openweathermap.org/data/2.5/find?q=lampa,pe&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 53 | MWINILUNGA
# http://api.openweathermap.org/data/2.5/find?q=mwinilunga,zm&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# No results for city halalo found!
# No results for city raga found!
# Processing Record 54 | PRIEGO DE CORDOBA
# http://api.openweathermap.org/data/2.5/find?q=priego%20de%20cordoba,es&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 55 | ODIENNE
# http://api.openweathermap.org/data/2.5/find?q=odienne,ci&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 56 | MARAGOGI
# http://api.openweathermap.org/data/2.5/find?q=maragogi,br&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 57 | CARMAUX
# http://api.openweathermap.org/data/2.5/find?q=carmaux,fr&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 58 | SEVEROBAYKALSK
# http://api.openweathermap.org/data/2.5/find?q=severobaykalsk,ru&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 59 | BAYANDAY
# http://api.openweathermap.org/data/2.5/find?q=bayanday,ru&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 60 | ANLOGA
# http://api.openweathermap.org/data/2.5/find?q=anloga,gh&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 61 | GUSAU
# http://api.openweathermap.org/data/2.5/find?q=gusau,ng&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 62 | KARAMAN
# http://api.openweathermap.org/data/2.5/find?q=karaman,tr&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 63 | DUSTLIK
# http://api.openweathermap.org/data/2.5/find?q=dustlik,uz&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 64 | SANTA CRUZ DE LA PALMA
# http://api.openweathermap.org/data/2.5/find?q=santa%20cruz%20de%20la%20palma,es&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 65 | NEWPORT
# http://api.openweathermap.org/data/2.5/find?q=newport,us&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 66 | ALIHE
# http://api.openweathermap.org/data/2.5/find?q=alihe,cn&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 67 | CAP-AUX-MEULES
# http://api.openweathermap.org/data/2.5/find?q=cap-aux-meules,ca&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 68 | SAINT-PAUL
# http://api.openweathermap.org/data/2.5/find?q=saint-paul,re&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 69 | PORTO NOVO
# http://api.openweathermap.org/data/2.5/find?q=porto%20novo,cv&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 70 | TABOU
# http://api.openweathermap.org/data/2.5/find?q=tabou,ci&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 71 | BUSINGA
# http://api.openweathermap.org/data/2.5/find?q=businga,cd&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 72 | AMBOVOMBE
# http://api.openweathermap.org/data/2.5/find?q=ambovombe,mg&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 73 | SHERIDAN
# http://api.openweathermap.org/data/2.5/find?q=sheridan,us&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 74 | MARANG
# http://api.openweathermap.org/data/2.5/find?q=marang,my&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 75 | SANTA CATARINA DE TEPEHUANES
# http://api.openweathermap.org/data/2.5/find?q=santa%20catarina%20de%20tepehuanes,mx&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 76 | CALABOZO
# http://api.openweathermap.org/data/2.5/find?q=calabozo,ve&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 77 | NAJRAN
# http://api.openweathermap.org/data/2.5/find?q=najran,sa&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 78 | ADRE
# http://api.openweathermap.org/data/2.5/find?q=adre,td&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 79 | BASQAL
# http://api.openweathermap.org/data/2.5/find?q=basqal,az&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 80 | NEEPAWA
# http://api.openweathermap.org/data/2.5/find?q=neepawa,ca&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# No results for city pafos found!
# Processing Record 81 | BELAYA GORA
# http://api.openweathermap.org/data/2.5/find?q=belaya%20gora,ru&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 82 | STAROGARD GDANSKI
# http://api.openweathermap.org/data/2.5/find?q=starogard%20gdanski,pl&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 83 | PORT-CARTIER
# http://api.openweathermap.org/data/2.5/find?q=port-cartier,ca&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 84 | KERCHEVSKIY
# http://api.openweathermap.org/data/2.5/find?q=kerchevskiy,ru&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 85 | BATSFJORD
# http://api.openweathermap.org/data/2.5/find?q=batsfjord,no&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 86 | PANZHIHUA
# http://api.openweathermap.org/data/2.5/find?q=panzhihua,cn&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 87 | YAMADA
# http://api.openweathermap.org/data/2.5/find?q=yamada,jp&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 88 | BOOUE
# http://api.openweathermap.org/data/2.5/find?q=booue,ga&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# No results for city sorvag found!
# Processing Record 89 | URDOMA
# http://api.openweathermap.org/data/2.5/find?q=urdoma,ru&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 90 | BELONIA
# http://api.openweathermap.org/data/2.5/find?q=belonia,in&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 91 | KITIMAT
# http://api.openweathermap.org/data/2.5/find?q=kitimat,ca&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 92 | LYUBIM
# http://api.openweathermap.org/data/2.5/find?q=lyubim,ru&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 93 | WAIPAWA
# http://api.openweathermap.org/data/2.5/find?q=waipawa,nz&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 94 | MALAZGIRT
# http://api.openweathermap.org/data/2.5/find?q=malazgirt,tr&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 95 | LIPARI
# http://api.openweathermap.org/data/2.5/find?q=lipari,it&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 96 | PITEA
# http://api.openweathermap.org/data/2.5/find?q=pitea,se&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 97 | LUAU
# http://api.openweathermap.org/data/2.5/find?q=luau,ao&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 98 | ARONA
# http://api.openweathermap.org/data/2.5/find?q=arona,es&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# No results for city louisbourg found!
# Processing Record 99 | CHERNYSHEVSKIY
# http://api.openweathermap.org/data/2.5/find?q=chernyshevskiy,ru&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# No results for city okandja found!
# Processing Record 100 | OPOLE
# http://api.openweathermap.org/data/2.5/find?q=opole,pl&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 101 | TECHIMAN
# http://api.openweathermap.org/data/2.5/find?q=techiman,gh&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 102 | NOVYY ROGACHIK
# http://api.openweathermap.org/data/2.5/find?q=novyy%20rogachik,ru&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 103 | ELKO
# http://api.openweathermap.org/data/2.5/find?q=elko,us&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 104 | SANTA FE
# http://api.openweathermap.org/data/2.5/find?q=santa%20fe,us&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 105 | JARDIM
# http://api.openweathermap.org/data/2.5/find?q=jardim,br&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 106 | LUMPHAT
# http://api.openweathermap.org/data/2.5/find?q=lumphat,kh&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 107 | RANONG
# http://api.openweathermap.org/data/2.5/find?q=ranong,th&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# No results for city jabiru found!
# No results for city abu samrah found!
# No results for city solovetskiy found!
# Processing Record 108 | BOGANDE
# http://api.openweathermap.org/data/2.5/find?q=bogande,bf&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 109 | MISHELEVKA
# http://api.openweathermap.org/data/2.5/find?q=mishelevka,ru&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 110 | SAYAT
# http://api.openweathermap.org/data/2.5/find?q=sayat,tm&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# No results for city dianopolis found!
# Processing Record 111 | CATACAOS
# http://api.openweathermap.org/data/2.5/find?q=catacaos,pe&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 112 | MARRAKESH
# http://api.openweathermap.org/data/2.5/find?q=marrakesh,ma&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 113 | OEIRAS
# http://api.openweathermap.org/data/2.5/find?q=oeiras,br&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 114 | MAHENGE
# http://api.openweathermap.org/data/2.5/find?q=mahenge,tz&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 115 | MALUMFASHI
# http://api.openweathermap.org/data/2.5/find?q=malumfashi,ng&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# No results for city satitoa found!
# Processing Record 116 | ARAOUANE
# http://api.openweathermap.org/data/2.5/find?q=araouane,ml&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 117 | HORODNYTSYA
# http://api.openweathermap.org/data/2.5/find?q=horodnytsya,ua&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 118 | KARLSTAD
# http://api.openweathermap.org/data/2.5/find?q=karlstad,se&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 119 | LENSK
# http://api.openweathermap.org/data/2.5/find?q=lensk,ru&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 120 | ULAANGOM
# http://api.openweathermap.org/data/2.5/find?q=ulaangom,mn&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 121 | MINA
# http://api.openweathermap.org/data/2.5/find?q=mina,ph&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 122 | LUANDA
# http://api.openweathermap.org/data/2.5/find?q=luanda,ao&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 123 | KHARP
# http://api.openweathermap.org/data/2.5/find?q=kharp,ru&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 124 | VILLAMONTES
# http://api.openweathermap.org/data/2.5/find?q=villamontes,bo&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 125 | JAMMALAMADUGU
# http://api.openweathermap.org/data/2.5/find?q=jammalamadugu,in&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 126 | SAMBAVA
# http://api.openweathermap.org/data/2.5/find?q=sambava,mg&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 127 | FERME-NEUVE
# http://api.openweathermap.org/data/2.5/find?q=ferme-neuve,ca&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 128 | LA CAROLINA
# http://api.openweathermap.org/data/2.5/find?q=la%20carolina,es&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 129 | MANADHOO
# http://api.openweathermap.org/data/2.5/find?q=manadhoo,mv&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 130 | MOSES LAKE
# http://api.openweathermap.org/data/2.5/find?q=moses%20lake,us&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 131 | UKIAH
# http://api.openweathermap.org/data/2.5/find?q=ukiah,us&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 132 | DOKA
# http://api.openweathermap.org/data/2.5/find?q=doka,sd&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 133 | CILAOS
# http://api.openweathermap.org/data/2.5/find?q=cilaos,re&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 134 | BARACOA
# http://api.openweathermap.org/data/2.5/find?q=baracoa,cu&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 135 | HACHINOHE
# http://api.openweathermap.org/data/2.5/find?q=hachinohe,jp&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 136 | ITAITUBA
# http://api.openweathermap.org/data/2.5/find?q=itaituba,br&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 137 | BALABAC
# http://api.openweathermap.org/data/2.5/find?q=balabac,ph&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# No results for city yirol found!
# Processing Record 138 | SEVERO-YENISEYSKIY
# http://api.openweathermap.org/data/2.5/find?q=severo-yeniseyskiy,ru&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 139 | TABATINGA
# http://api.openweathermap.org/data/2.5/find?q=tabatinga,br&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 140 | HRUBIESZOW
# http://api.openweathermap.org/data/2.5/find?q=hrubieszow,pl&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 141 | LILLOOET
# http://api.openweathermap.org/data/2.5/find?q=lillooet,ca&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 142 | DALVIK
# http://api.openweathermap.org/data/2.5/find?q=dalvik,is&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 143 | TABANAN
# http://api.openweathermap.org/data/2.5/find?q=tabanan,id&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# No results for city aporawan found!
# Processing Record 144 | RUDBAR
# http://api.openweathermap.org/data/2.5/find?q=rudbar,af&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 145 | HAY RIVER
# http://api.openweathermap.org/data/2.5/find?q=hay%20river,ca&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 146 | LAMBALLE
# http://api.openweathermap.org/data/2.5/find?q=lamballe,fr&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 147 | SEMINOLE
# http://api.openweathermap.org/data/2.5/find?q=seminole,us&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 148 | NORTH BEND
# http://api.openweathermap.org/data/2.5/find?q=north%20bend,us&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 149 | HEMNESBERGET
# http://api.openweathermap.org/data/2.5/find?q=hemnesberget,no&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 150 | TRABZON
# http://api.openweathermap.org/data/2.5/find?q=trabzon,tr&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 151 | BERDSK
# http://api.openweathermap.org/data/2.5/find?q=berdsk,ru&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 152 | BEATRICE
# http://api.openweathermap.org/data/2.5/find?q=beatrice,us&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 153 | DARGAVILLE
# http://api.openweathermap.org/data/2.5/find?q=dargaville,nz&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 154 | SOMBRIO
# http://api.openweathermap.org/data/2.5/find?q=sombrio,br&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 155 | CAROLINA
# http://api.openweathermap.org/data/2.5/find?q=carolina,br&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 156 | GUASDUALITO
# http://api.openweathermap.org/data/2.5/find?q=guasdualito,ve&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 157 | MUS
# http://api.openweathermap.org/data/2.5/find?q=mus,tr&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 158 | SANTA ROSA
# http://api.openweathermap.org/data/2.5/find?q=santa%20rosa,ar&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 159 | KINGAROY
# http://api.openweathermap.org/data/2.5/find?q=kingaroy,au&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 160 | ATHERTON
# http://api.openweathermap.org/data/2.5/find?q=atherton,au&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 161 | WEIMAR
# http://api.openweathermap.org/data/2.5/find?q=weimar,de&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# No results for city sakakah found!
# Processing Record 162 | CHALUS
# http://api.openweathermap.org/data/2.5/find?q=chalus,ir&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 163 | NOLA
# http://api.openweathermap.org/data/2.5/find?q=nola,cf&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 164 | THOEN
# http://api.openweathermap.org/data/2.5/find?q=thoen,th&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 165 | CUMARU
# http://api.openweathermap.org/data/2.5/find?q=cumaru,br&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# No results for city haibowan found!
# Processing Record 166 | BALANGIGA
# http://api.openweathermap.org/data/2.5/find?q=balangiga,ph&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 167 | GUALEGUAY
# http://api.openweathermap.org/data/2.5/find?q=gualeguay,ar&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 168 | CEDAR CITY
# http://api.openweathermap.org/data/2.5/find?q=cedar%20city,us&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 169 | SKERRIES
# http://api.openweathermap.org/data/2.5/find?q=skerries,ie&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 170 | TUCUMCARI
# http://api.openweathermap.org/data/2.5/find?q=tucumcari,us&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 171 | TANCHENG
# http://api.openweathermap.org/data/2.5/find?q=tancheng,cn&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 172 | LEH
# http://api.openweathermap.org/data/2.5/find?q=leh,in&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 173 | SMITHERS
# http://api.openweathermap.org/data/2.5/find?q=smithers,ca&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 174 | VIZIANAGARAM
# http://api.openweathermap.org/data/2.5/find?q=vizianagaram,in&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 175 | MANGROL
# http://api.openweathermap.org/data/2.5/find?q=mangrol,in&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# No results for city scottsburgh found!
# No results for city salani found!
# Processing Record 176 | FLAGSTAFF
# http://api.openweathermap.org/data/2.5/find?q=flagstaff,us&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 177 | GERALDTON
# http://api.openweathermap.org/data/2.5/find?q=geraldton,ca&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 178 | KHASAN
# http://api.openweathermap.org/data/2.5/find?q=khasan,ru&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 179 | SAN RAMON
# http://api.openweathermap.org/data/2.5/find?q=san%20ramon,bo&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 180 | OLAYA
# http://api.openweathermap.org/data/2.5/find?q=olaya,co&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# No results for city bolshoy tsaryn found!
# Processing Record 181 | NUEVO IMPERIAL
# http://api.openweathermap.org/data/2.5/find?q=nuevo%20imperial,pe&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 182 | MOCTEZUMA
# http://api.openweathermap.org/data/2.5/find?q=moctezuma,mx&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 183 | SUNBURY
# http://api.openweathermap.org/data/2.5/find?q=sunbury,us&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 184 | HERVEY BAY
# http://api.openweathermap.org/data/2.5/find?q=hervey%20bay,au&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 185 | BARKOT
# http://api.openweathermap.org/data/2.5/find?q=barkot,in&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 186 | ELLENABAD
# http://api.openweathermap.org/data/2.5/find?q=ellenabad,in&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 187 | PUERTO AYACUCHO
# http://api.openweathermap.org/data/2.5/find?q=puerto%20ayacucho,ve&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 188 | MANINGRIDA
# http://api.openweathermap.org/data/2.5/find?q=maningrida,au&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 189 | VUKTYL
# http://api.openweathermap.org/data/2.5/find?q=vuktyl,ru&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 190 | BAMBARI
# http://api.openweathermap.org/data/2.5/find?q=bambari,cf&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 191 | HILTON HEAD ISLAND
# http://api.openweathermap.org/data/2.5/find?q=hilton%20head%20island,us&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 192 | KABALO
# http://api.openweathermap.org/data/2.5/find?q=kabalo,cd&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 193 | OTRADNOYE
# http://api.openweathermap.org/data/2.5/find?q=otradnoye,ru&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 194 | MALTAHOHE
# http://api.openweathermap.org/data/2.5/find?q=maltahohe,na&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 195 | CARNARVON
# http://api.openweathermap.org/data/2.5/find?q=carnarvon,za&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 196 | BEITBRIDGE
# http://api.openweathermap.org/data/2.5/find?q=beitbridge,zw&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 197 | KURAGINO
# http://api.openweathermap.org/data/2.5/find?q=kuragino,ru&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 198 | TIGIL
# http://api.openweathermap.org/data/2.5/find?q=tigil,ru&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 199 | GAZOJAK
# http://api.openweathermap.org/data/2.5/find?q=gazojak,tm&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 200 | CARBALLO
# http://api.openweathermap.org/data/2.5/find?q=carballo,es&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 201 | HUNTSVILLE
# http://api.openweathermap.org/data/2.5/find?q=huntsville,us&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 202 | SAINT-FRANCOIS
# http://api.openweathermap.org/data/2.5/find?q=saint-francois,gp&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 203 | HASTINGS
# http://api.openweathermap.org/data/2.5/find?q=hastings,us&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 204 | COROMANDEL
# http://api.openweathermap.org/data/2.5/find?q=coromandel,nz&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 205 | VIZINGA
# http://api.openweathermap.org/data/2.5/find?q=vizinga,ru&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 206 | DIVNOGORSK
# http://api.openweathermap.org/data/2.5/find?q=divnogorsk,ru&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 207 | CAMOPI
# http://api.openweathermap.org/data/2.5/find?q=camopi,gf&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 208 | PALU
# http://api.openweathermap.org/data/2.5/find?q=palu,id&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 209 | ARRECIFE
# http://api.openweathermap.org/data/2.5/find?q=arrecife,es&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 210 | OXFORD
# http://api.openweathermap.org/data/2.5/find?q=oxford,gb&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 211 | EGANVILLE
# http://api.openweathermap.org/data/2.5/find?q=eganville,ca&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 212 | MANITOUWADGE
# http://api.openweathermap.org/data/2.5/find?q=manitouwadge,ca&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 213 | BARZAS
# http://api.openweathermap.org/data/2.5/find?q=barzas,ru&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 214 | NORTHAM
# http://api.openweathermap.org/data/2.5/find?q=northam,au&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 215 | GRAND-LAHOU
# http://api.openweathermap.org/data/2.5/find?q=grand-lahou,ci&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 216 | NIZHNIY KURANAKH
# http://api.openweathermap.org/data/2.5/find?q=nizhniy%20kuranakh,ru&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 217 | MOZELOS
# http://api.openweathermap.org/data/2.5/find?q=mozelos,pt&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 218 | MIRNYY
# http://api.openweathermap.org/data/2.5/find?q=mirnyy,ru&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# No results for city malwan found!
# Processing Record 219 | FLIN FLON
# http://api.openweathermap.org/data/2.5/find?q=flin%20flon,ca&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 220 | KENORA
# http://api.openweathermap.org/data/2.5/find?q=kenora,ca&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# No results for city malakal found!
# Processing Record 221 | SINEGORYE
# http://api.openweathermap.org/data/2.5/find?q=sinegorye,ru&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 222 | PARAMONGA
# http://api.openweathermap.org/data/2.5/find?q=paramonga,pe&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 223 | ZHUHAI
# http://api.openweathermap.org/data/2.5/find?q=zhuhai,cn&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 224 | FORT SAINT JAMES
# http://api.openweathermap.org/data/2.5/find?q=fort%20saint%20james,ca&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# No results for city buqayq found!
# Processing Record 225 | XIAMEN
# http://api.openweathermap.org/data/2.5/find?q=xiamen,cn&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 226 | KEARNEY
# http://api.openweathermap.org/data/2.5/find?q=kearney,us&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 227 | BOGORODSKOYE
# http://api.openweathermap.org/data/2.5/find?q=bogorodskoye,ru&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 228 | PIERRE
# http://api.openweathermap.org/data/2.5/find?q=pierre,us&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# No results for city sinubung found!
# Processing Record 229 | TORNIO
# http://api.openweathermap.org/data/2.5/find?q=tornio,fi&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 230 | TEMPLE
# http://api.openweathermap.org/data/2.5/find?q=temple,us&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 231 | PORT HUENEME
# http://api.openweathermap.org/data/2.5/find?q=port%20hueneme,us&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 232 | BICHENA
# http://api.openweathermap.org/data/2.5/find?q=bichena,et&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 233 | STATE COLLEGE
# http://api.openweathermap.org/data/2.5/find?q=state%20college,us&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 234 | ARCHIDONA
# http://api.openweathermap.org/data/2.5/find?q=archidona,ec&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 235 | SUHBAATAR
# http://api.openweathermap.org/data/2.5/find?q=suhbaatar,mn&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# No results for city toliary found!
# Processing Record 236 | ISHIGAKI
# http://api.openweathermap.org/data/2.5/find?q=ishigaki,jp&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 237 | GEORGETOWN
# http://api.openweathermap.org/data/2.5/find?q=georgetown,us&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 238 | MOGILNO
# http://api.openweathermap.org/data/2.5/find?q=mogilno,pl&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 239 | KOCHEVO
# http://api.openweathermap.org/data/2.5/find?q=kochevo,ru&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# No results for city tidore found!
# Processing Record 240 | PALMARES DO SUL
# http://api.openweathermap.org/data/2.5/find?q=palmares%20do%20sul,br&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 241 | MAYOR PABLO LAGERENZA
# http://api.openweathermap.org/data/2.5/find?q=mayor%20pablo%20lagerenza,py&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 242 | HOSHIARPUR
# http://api.openweathermap.org/data/2.5/find?q=hoshiarpur,in&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# No results for city tabiauea found!
# Processing Record 243 | ROMILLY-SUR-SEINE
# http://api.openweathermap.org/data/2.5/find?q=romilly-sur-seine,fr&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 244 | SAINT JOSEPH
# http://api.openweathermap.org/data/2.5/find?q=saint%20joseph,us&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 245 | SAN JOSE DEL PALMAR
# http://api.openweathermap.org/data/2.5/find?q=san%20jose%20del%20palmar,co&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 246 | MEHRIZ
# http://api.openweathermap.org/data/2.5/find?q=mehriz,ir&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 247 | VAITAPE
# http://api.openweathermap.org/data/2.5/find?q=vaitape,pf&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 248 | OKAHANDJA
# http://api.openweathermap.org/data/2.5/find?q=okahandja,na&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 249 | ZILUPE
# http://api.openweathermap.org/data/2.5/find?q=zilupe,lv&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 250 | GIZO
# http://api.openweathermap.org/data/2.5/find?q=gizo,sb&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 251 | DENPASAR
# http://api.openweathermap.org/data/2.5/find?q=denpasar,id&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 252 | CORACORA
# http://api.openweathermap.org/data/2.5/find?q=coracora,pe&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 253 | ABORLAN
# http://api.openweathermap.org/data/2.5/find?q=aborlan,ph&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 254 | TROGIR
# http://api.openweathermap.org/data/2.5/find?q=trogir,hr&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 255 | ANAPOLIS
# http://api.openweathermap.org/data/2.5/find?q=anapolis,br&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 256 | MOUNTAIN HOME
# http://api.openweathermap.org/data/2.5/find?q=mountain%20home,us&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 257 | ATIKOKAN
# http://api.openweathermap.org/data/2.5/find?q=atikokan,ca&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 258 | SULPHUR SPRINGS
# http://api.openweathermap.org/data/2.5/find?q=sulphur%20springs,us&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 259 | VANINO
# http://api.openweathermap.org/data/2.5/find?q=vanino,ru&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 260 | MATAGAMI
# http://api.openweathermap.org/data/2.5/find?q=matagami,ca&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 261 | BELLA VISTA
# http://api.openweathermap.org/data/2.5/find?q=bella%20vista,py&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 262 | MURIWAI BEACH
# http://api.openweathermap.org/data/2.5/find?q=muriwai%20beach,nz&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 263 | KUSHALGARH
# http://api.openweathermap.org/data/2.5/find?q=kushalgarh,in&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 264 | MERAUKE
# http://api.openweathermap.org/data/2.5/find?q=merauke,id&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 265 | HAVELOCK
# http://api.openweathermap.org/data/2.5/find?q=havelock,us&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 266 | OPUWO
# http://api.openweathermap.org/data/2.5/find?q=opuwo,na&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 267 | BOGUCHANY
# http://api.openweathermap.org/data/2.5/find?q=boguchany,ru&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 268 | KARGIL
# http://api.openweathermap.org/data/2.5/find?q=kargil,in&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# No results for city bolungarvik found!
# Processing Record 269 | GUA MUSANG
# http://api.openweathermap.org/data/2.5/find?q=gua%20musang,my&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 270 | KITA
# http://api.openweathermap.org/data/2.5/find?q=kita,ml&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 271 | GUNJUR
# http://api.openweathermap.org/data/2.5/find?q=gunjur,gm&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 272 | CAPE GIRARDEAU
# http://api.openweathermap.org/data/2.5/find?q=cape%20girardeau,us&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 273 | SOLANO
# http://api.openweathermap.org/data/2.5/find?q=solano,co&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 274 | KUPANG
# http://api.openweathermap.org/data/2.5/find?q=kupang,id&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 275 | SANTA ISABEL DO RIO NEGRO
# http://api.openweathermap.org/data/2.5/find?q=santa%20isabel%20do%20rio%20negro,br&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 276 | BELIZE
# http://api.openweathermap.org/data/2.5/find?q=belize,bz&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 277 | EYL
# http://api.openweathermap.org/data/2.5/find?q=eyl,so&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 278 | TORIBIO
# http://api.openweathermap.org/data/2.5/find?q=toribio,co&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 279 | LABYTNANGI
# http://api.openweathermap.org/data/2.5/find?q=labytnangi,ru&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 280 | SANTA CRUZ
# http://api.openweathermap.org/data/2.5/find?q=santa%20cruz,cr&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 281 | BUNIA
# http://api.openweathermap.org/data/2.5/find?q=bunia,cd&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 282 | KEY WEST
# http://api.openweathermap.org/data/2.5/find?q=key%20west,us&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 283 | SAZONOVO
# http://api.openweathermap.org/data/2.5/find?q=sazonovo,ru&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 284 | YINING
# http://api.openweathermap.org/data/2.5/find?q=yining,cn&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# No results for city phan rang found!
# Processing Record 285 | MATAY
# http://api.openweathermap.org/data/2.5/find?q=matay,eg&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 286 | LISAKOVSK
# http://api.openweathermap.org/data/2.5/find?q=lisakovsk,kz&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 287 | BERBERA
# http://api.openweathermap.org/data/2.5/find?q=berbera,so&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 288 | NOSHIRO
# http://api.openweathermap.org/data/2.5/find?q=noshiro,jp&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 289 | SEDDON
# http://api.openweathermap.org/data/2.5/find?q=seddon,nz&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 290 | TETE
# http://api.openweathermap.org/data/2.5/find?q=tete,mz&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# No results for city ormos korthiou found!
# Processing Record 291 | ABANCAY
# http://api.openweathermap.org/data/2.5/find?q=abancay,pe&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 292 | YAR-SALE
# http://api.openweathermap.org/data/2.5/find?q=yar-sale,ru&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# No results for city bac lieu found!
# Processing Record 293 | SUBA
# http://api.openweathermap.org/data/2.5/find?q=suba,ph&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 294 | VILLAFRANCA DI VERONA
# http://api.openweathermap.org/data/2.5/find?q=villafranca%20di%20verona,it&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 295 | CHINHOYI
# http://api.openweathermap.org/data/2.5/find?q=chinhoyi,zw&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 296 | ARIMA
# http://api.openweathermap.org/data/2.5/find?q=arima,tt&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 297 | COLLIE
# http://api.openweathermap.org/data/2.5/find?q=collie,au&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 298 | SOCHI
# http://api.openweathermap.org/data/2.5/find?q=sochi,ru&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 299 | USAGARA
# http://api.openweathermap.org/data/2.5/find?q=usagara,tz&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 300 | CATTOLICA
# http://api.openweathermap.org/data/2.5/find?q=cattolica,it&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 301 | BUNDABERG
# http://api.openweathermap.org/data/2.5/find?q=bundaberg,au&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 302 | LEON
# http://api.openweathermap.org/data/2.5/find?q=leon,ni&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 303 | FALMOUTH
# http://api.openweathermap.org/data/2.5/find?q=falmouth,gb&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 304 | SHENZHEN
# http://api.openweathermap.org/data/2.5/find?q=shenzhen,cn&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 305 | MATTRU
# http://api.openweathermap.org/data/2.5/find?q=mattru,sl&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 306 | LICHUAN
# http://api.openweathermap.org/data/2.5/find?q=lichuan,cn&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# No results for city rolim de moura found!
# No results for city tartus found!
# No results for city lephepe found!
# Processing Record 307 | CANICO
# http://api.openweathermap.org/data/2.5/find?q=canico,pt&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 308 | OKATO
# http://api.openweathermap.org/data/2.5/find?q=okato,nz&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 309 | MORTKA
# http://api.openweathermap.org/data/2.5/find?q=mortka,ru&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 310 | VYAZMA
# http://api.openweathermap.org/data/2.5/find?q=vyazma,ru&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 311 | NENJIANG
# http://api.openweathermap.org/data/2.5/find?q=nenjiang,cn&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 312 | CERTEGUI
# http://api.openweathermap.org/data/2.5/find?q=certegui,co&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 313 | KUAH
# http://api.openweathermap.org/data/2.5/find?q=kuah,my&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 314 | FALLON
# http://api.openweathermap.org/data/2.5/find?q=fallon,us&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 315 | INDIANA
# http://api.openweathermap.org/data/2.5/find?q=indiana,us&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 316 | ORNSKOLDSVIK
# http://api.openweathermap.org/data/2.5/find?q=ornskoldsvik,se&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 317 | KANGAATSIAQ
# http://api.openweathermap.org/data/2.5/find?q=kangaatsiaq,gl&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 318 | WE
# http://api.openweathermap.org/data/2.5/find?q=we,nc&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# No results for city doha found!
# Processing Record 319 | ABNUB
# http://api.openweathermap.org/data/2.5/find?q=abnub,eg&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 320 | RAMANA
# ...
# Processing Record 395 | MIZAN TEFERI
# http://api.openweathermap.org/data/2.5/find?q=mizan%20teferi,et&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# No results for city rincon found!
# Processing Record 396 | SABHA
# http://api.openweathermap.org/data/2.5/find?q=sabha,ly&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 397 | ADILABAD
# http://api.openweathermap.org/data/2.5/find?q=adilabad,in&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 398 | LA LIBERTAD
# http://api.openweathermap.org/data/2.5/find?q=la%20libertad,sv&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# No results for city cabo rojo found!
# Processing Record 399 | BAKO
# http://api.openweathermap.org/data/2.5/find?q=bako,et&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 400 | VANCOUVER
# http://api.openweathermap.org/data/2.5/find?q=vancouver,ca&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 401 | TEKKALI
# http://api.openweathermap.org/data/2.5/find?q=tekkali,in&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 402 | KIZUKURI
# http://api.openweathermap.org/data/2.5/find?q=kizukuri,jp&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 403 | DEN HELDER
# http://api.openweathermap.org/data/2.5/find?q=den%20helder,nl&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 404 | XIONGYUE
# http://api.openweathermap.org/data/2.5/find?q=xiongyue,cn&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 405 | HAMMERFEST
# http://api.openweathermap.org/data/2.5/find?q=hammerfest,no&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 406 | OVALLE
# http://api.openweathermap.org/data/2.5/find?q=ovalle,cl&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 407 | HORSHAM
# http://api.openweathermap.org/data/2.5/find?q=horsham,au&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 408 | SON LA
# http://api.openweathermap.org/data/2.5/find?q=son%20la,vn&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 409 | ALAMOS
# http://api.openweathermap.org/data/2.5/find?q=alamos,mx&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 410 | LUBA
# http://api.openweathermap.org/data/2.5/find?q=luba,gq&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 411 | RIBAS DO RIO PARDO
# http://api.openweathermap.org/data/2.5/find?q=ribas%20do%20rio%20pardo,br&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 412 | OYONNAX
# http://api.openweathermap.org/data/2.5/find?q=oyonnax,fr&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 413 | ABALAK
# http://api.openweathermap.org/data/2.5/find?q=abalak,ne&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 414 | DRACUT
# http://api.openweathermap.org/data/2.5/find?q=dracut,us&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 415 | BOLLNAS
# http://api.openweathermap.org/data/2.5/find?q=bollnas,se&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 416 | CONSTANTINE
# http://api.openweathermap.org/data/2.5/find?q=constantine,dz&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 417 | CUMBERLAND
# http://api.openweathermap.org/data/2.5/find?q=cumberland,us&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 418 | QUELIMANE
# http://api.openweathermap.org/data/2.5/find?q=quelimane,mz&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 419 | SIDERNO
# http://api.openweathermap.org/data/2.5/find?q=siderno,it&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 420 | SHAUNAVON
# http://api.openweathermap.org/data/2.5/find?q=shaunavon,ca&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 421 | CHATEAUBELAIR
# http://api.openweathermap.org/data/2.5/find?q=chateaubelair,vc&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 422 | KLOULKLUBED
# http://api.openweathermap.org/data/2.5/find?q=kloulklubed,pw&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 423 | SERENJE
# http://api.openweathermap.org/data/2.5/find?q=serenje,zm&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 424 | KAMIICHI
# http://api.openweathermap.org/data/2.5/find?q=kamiichi,jp&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 425 | LUKANG
# http://api.openweathermap.org/data/2.5/find?q=lukang,tw&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# No results for city birin found!
# Processing Record 426 | TRAIRI
# http://api.openweathermap.org/data/2.5/find?q=trairi,br&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 427 | NOWOGARD
# http://api.openweathermap.org/data/2.5/find?q=nowogard,pl&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 428 | DANVILLE
# http://api.openweathermap.org/data/2.5/find?q=danville,us&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 429 | KHARABALI
# http://api.openweathermap.org/data/2.5/find?q=kharabali,ru&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 430 | CHIVAY
# http://api.openweathermap.org/data/2.5/find?q=chivay,pe&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 431 | TALARA
# http://api.openweathermap.org/data/2.5/find?q=talara,pe&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# No results for city canitas found!
# Processing Record 432 | TSHIKAPA
# http://api.openweathermap.org/data/2.5/find?q=tshikapa,cd&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 433 | SAMSUN
# http://api.openweathermap.org/data/2.5/find?q=samsun,tr&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 434 | TUMBAGAAN
# http://api.openweathermap.org/data/2.5/find?q=tumbagaan,ph&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# No results for city fevralsk found!
# Processing Record 435 | PLETTENBERG BAY
# http://api.openweathermap.org/data/2.5/find?q=plettenberg%20bay,za&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# No results for city pousat found!
# Processing Record 436 | GARDELEGEN
# http://api.openweathermap.org/data/2.5/find?q=gardelegen,de&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 437 | MBANDAKA
# http://api.openweathermap.org/data/2.5/find?q=mbandaka,cd&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 438 | MAKALENG
# http://api.openweathermap.org/data/2.5/find?q=makaleng,bw&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 439 | MADANG
# http://api.openweathermap.org/data/2.5/find?q=madang,pg&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 440 | ZHEZKAZGAN
# http://api.openweathermap.org/data/2.5/find?q=zhezkazgan,kz&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 441 | CLIFTON
# http://api.openweathermap.org/data/2.5/find?q=clifton,us&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 442 | AKSU
# http://api.openweathermap.org/data/2.5/find?q=aksu,cn&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 443 | STERLING
# http://api.openweathermap.org/data/2.5/find?q=sterling,us&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# No results for city karamea found!
# Processing Record 444 | BOYOLANGU
# http://api.openweathermap.org/data/2.5/find?q=boyolangu,id&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 445 | NOUAKCHOTT
# http://api.openweathermap.org/data/2.5/find?q=nouakchott,mr&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 446 | TRIPOLI
# http://api.openweathermap.org/data/2.5/find?q=tripoli,ly&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 447 | TALCAHUANO
# http://api.openweathermap.org/data/2.5/find?q=talcahuano,cl&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 448 | DELAWARE
# http://api.openweathermap.org/data/2.5/find?q=delaware,us&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 449 | KATOBU
# http://api.openweathermap.org/data/2.5/find?q=katobu,id&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 450 | NEVSEHIR
# http://api.openweathermap.org/data/2.5/find?q=nevsehir,tr&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 451 | COPIAPO
# http://api.openweathermap.org/data/2.5/find?q=copiapo,cl&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 452 | KIDDERMINSTER
# http://api.openweathermap.org/data/2.5/find?q=kidderminster,gb&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 453 | SORATA
# http://api.openweathermap.org/data/2.5/find?q=sorata,bo&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 454 | KOTKA
# http://api.openweathermap.org/data/2.5/find?q=kotka,fi&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 455 | YIYANG
# http://api.openweathermap.org/data/2.5/find?q=yiyang,cn&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 456 | KATHU
# http://api.openweathermap.org/data/2.5/find?q=kathu,za&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 457 | BEHBAHAN
# http://api.openweathermap.org/data/2.5/find?q=behbahan,ir&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 458 | SENNETERRE
# http://api.openweathermap.org/data/2.5/find?q=senneterre,ca&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 459 | OKTYABRSKOYE
# http://api.openweathermap.org/data/2.5/find?q=oktyabrskoye,ru&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 460 | MARYSTOWN
# http://api.openweathermap.org/data/2.5/find?q=marystown,ca&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 461 | POPONDETTA
# http://api.openweathermap.org/data/2.5/find?q=popondetta,pg&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# No results for city palaiokhora found!
# Processing Record 462 | VISBY
# http://api.openweathermap.org/data/2.5/find?q=visby,se&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 463 | SECHURA
# http://api.openweathermap.org/data/2.5/find?q=sechura,pe&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 464 | LAGUNAS
# http://api.openweathermap.org/data/2.5/find?q=lagunas,pe&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 465 | BATAGAY-ALYTA
# http://api.openweathermap.org/data/2.5/find?q=batagay-alyta,ru&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 466 | PANGODY
# http://api.openweathermap.org/data/2.5/find?q=pangody,ru&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 467 | BULGAN
# http://api.openweathermap.org/data/2.5/find?q=bulgan,mn&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 468 | SHEBALINO
# http://api.openweathermap.org/data/2.5/find?q=shebalino,ru&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# No results for city barbar found!
# Processing Record 469 | CHUMIKAN
# http://api.openweathermap.org/data/2.5/find?q=chumikan,ru&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 470 | BEIRA
# http://api.openweathermap.org/data/2.5/find?q=beira,mz&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 471 | VILLA CARLOS PAZ
# http://api.openweathermap.org/data/2.5/find?q=villa%20carlos%20paz,ar&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 472 | BEIPIAO
# http://api.openweathermap.org/data/2.5/find?q=beipiao,cn&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 473 | KIJANG
# http://api.openweathermap.org/data/2.5/find?q=kijang,id&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 474 | BANDA ACEH
# http://api.openweathermap.org/data/2.5/find?q=banda%20aceh,id&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# No results for city yurya found!
# Processing Record 475 | POHREBYSHCHE
# http://api.openweathermap.org/data/2.5/find?q=pohrebyshche,ua&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 476 | UMM LAJJ
# http://api.openweathermap.org/data/2.5/find?q=umm%20lajj,sa&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 477 | ASSAI
# http://api.openweathermap.org/data/2.5/find?q=assai,br&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# No results for city karamay found!
# Processing Record 478 | LANGSA
# http://api.openweathermap.org/data/2.5/find?q=langsa,id&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 479 | PARACURU
# http://api.openweathermap.org/data/2.5/find?q=paracuru,br&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# No results for city macaboboni found!
# Processing Record 480 | BYRON BAY
# http://api.openweathermap.org/data/2.5/find?q=byron%20bay,au&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 481 | KEMI
# http://api.openweathermap.org/data/2.5/find?q=kemi,fi&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 482 | DICABISAGAN
# http://api.openweathermap.org/data/2.5/find?q=dicabisagan,ph&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 483 | THINADHOO
# http://api.openweathermap.org/data/2.5/find?q=thinadhoo,mv&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 484 | BOURGES
# http://api.openweathermap.org/data/2.5/find?q=bourges,fr&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 485 | BRIGANTINE
# http://api.openweathermap.org/data/2.5/find?q=brigantine,us&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 486 | LIPIN BOR
# http://api.openweathermap.org/data/2.5/find?q=lipin%20bor,ru&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 487 | ROMA
# http://api.openweathermap.org/data/2.5/find?q=roma,au&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 488 | POMBAS
# http://api.openweathermap.org/data/2.5/find?q=pombas,cv&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 489 | OYAMA
# http://api.openweathermap.org/data/2.5/find?q=oyama,jp&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# No results for city camana found!
# Processing Record 490 | BELMONTE
# http://api.openweathermap.org/data/2.5/find?q=belmonte,br&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 491 | OWANDO
# http://api.openweathermap.org/data/2.5/find?q=owando,cg&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 492 | KUCHING
# http://api.openweathermap.org/data/2.5/find?q=kuching,my&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 493 | VANGAINDRANO
# http://api.openweathermap.org/data/2.5/find?q=vangaindrano,mg&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 494 | CAM RANH
# http://api.openweathermap.org/data/2.5/find?q=cam%20ranh,vn&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 495 | DAWSON CREEK
# http://api.openweathermap.org/data/2.5/find?q=dawson%20creek,ca&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 496 | MONCHEGORSK
# http://api.openweathermap.org/data/2.5/find?q=monchegorsk,ru&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# No results for city utiroa found!
# Processing Record 497 | PALLASOVKA
# http://api.openweathermap.org/data/2.5/find?q=pallasovka,ru&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 498 | MONTEPUEZ
# http://api.openweathermap.org/data/2.5/find?q=montepuez,mz&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 499 | WATSA
# http://api.openweathermap.org/data/2.5/find?q=watsa,cd&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 500 | QUANG NGAI
# http://api.openweathermap.org/data/2.5/find?q=quang%20ngai,vn&units=imperial&appid=25bc90a1196e6f153eece0bc0b0fc9eb
# 500 unique cities are ready for further analysis!

# %% [markdown]
# Step 6:
#
# In the next few cells, I use data wrangling methods within pandas dataframe to make the data readable and presentable.

# %%
# Define the new dataframe with 500 cities for visualization tasks

Weather_Summary_Cities_500 = Weather_Summary_Cities[Weather_Summary_Cities["Max_Temperature"] != ""]

# Reset the index and drop the column with existing index

Weather_Summary_Cities_500_Reindexed = Weather_Summary_Cities_500.reset_index(drop=True)

Weather_Summary_Cities_500_Reindexed.head()
# Out:
#           City Country_Code   Latitude   Longitude Max_Temperature Humidity  \
# 0       golden           ca  50.714955 -117.016938            87.8       19
# 1         teya           ru  62.604506   90.021160           65.03       58
# 2      mareeba           au -14.336150  144.720012            71.6       53
# 3  spring hill           us  29.166412  -83.000094            87.8       70
# 4     adjumani           ug   3.262658   32.184830           63.86       96
#
#   Cloudiness Wind_Speed
# 0         40        4.7
# 1         32       4.05
# 2         40      11.41
# 3          1       8.05
# 4         80       2.37

# %%
# Convert City to start with capital case ; Convert Country Coder to upper case

Weather_Summary_Cities_500_Reindexed["City"] = Weather_Summary_Cities_500_Reindexed.City.str.title()

Weather_Summary_Cities_500_Reindexed["Country_Code"] = Weather_Summary_Cities_500_Reindexed.Country_Code.str.upper()

# %%
Weather_Summary_Cities_500_Reindexed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
# City               500 non-null object
# Country_Code       500 non-null object
# Latitude           500 non-null float64
# Longitude          500 non-null float64
# Max_Temperature    500 non-null object
# Humidity           500 non-null object
# Cloudiness         500 non-null object
# Wind_Speed         500 non-null object
# dtypes: float64(2), object(6)
# memory usage: 31.3+ KB

# %%
# Create bins to identify temperature, humidity, Cloudiness. This will help in insightful visualizations
# The categories and bins have been indentified based on my experience, and readings / heat maps available through Google Images

Temp_Bin = [20,50,70,200]

Temp_Group_Names = ["Cold","Optimum","Hot"]

Weather_Summary_Cities_500_Reindexed["Temperature_Category"] = pd.cut(Weather_Summary_Cities_500_Reindexed["Max_Temperature"],
                                                                      Temp_Bin,labels=Temp_Group_Names)

Humidity_Bin = [0,35,75,101]

Humidity_Group_Names = ["Dry","Optimum","Moist"]

Weather_Summary_Cities_500_Reindexed["Humidity_Category"] = pd.cut(Weather_Summary_Cities_500_Reindexed["Humidity"],
                                                                      Humidity_Bin,labels=Humidity_Group_Names)

Cloudiness_Bin = [-1,30,70,101]

Cloudiness_Group_Names = ["Clear","Partly_Cloudy","Cloudy"]

Weather_Summary_Cities_500_Reindexed["Cloudiness_Category"] = pd.cut(Weather_Summary_Cities_500_Reindexed["Cloudiness"],
                                                            Cloudiness_Bin,labels=Cloudiness_Group_Names)

Weather_Summary_Cities_500_Reindexed.head()
# Out:
#           City Country_Code   Latitude   Longitude Max_Temperature Humidity  \
# 0       Golden           CA  50.714955 -117.016938            87.8       19
# 1         Teya           RU  62.604506   90.021160           65.03       58
# 2      Mareeba           AU -14.336150  144.720012            71.6       53
# 3  Spring Hill           US  29.166412  -83.000094            87.8       70
# 4     Adjumani           UG   3.262658   32.184830           63.86       96
#
#   Cloudiness Wind_Speed Temperature_Category Humidity_Category  \
# 0         40        4.7                  Hot               Dry
# 1         32       4.05              Optimum           Optimum
# 2         40      11.41                  Hot           Optimum
# 3          1       8.05                  Hot           Optimum
# 4         80       2.37              Optimum             Moist
#
#   Cloudiness_Category
# 0       Partly_Cloudy
# 1       Partly_Cloudy
# 2       Partly_Cloudy
# 3               Clear
# 4              Cloudy

# %% [markdown]
# Step 7 :
#
# I use seaborn libraries (lmplot) to plot the illustrate weather attributes vs Latitude.
#
# City Latitude vs Max Temperature -

# %%
# Define the lmplot structure

sns.set()

sns.set_context("notebook")

sns_plot1 = sns.lmplot( x="Latitude", y="Max_Temperature",size=6, data = Weather_Summary_Cities_500_Reindexed,fit_reg=False, 
           hue="Temperature_Category", legend=False, palette=dict(Cold="#0343df",Optimum="#01ff07",Hot="#e50000"))

Today_Date = str(date.today())

# Label the plot

Plot_Title = f"City Latitude vs Max Temperature: {Today_Date}"
plt.title(Plot_Title)

plt.xlabel("Latitude")
plt.ylabel("Max Temperature (°F)")

plt.xlim(-80,100)
plt.ylim(20, 120)

plt.legend(loc='upper left')

# Save the image and display

sns_plot1.savefig("../Images/Latitude_vs_MaxTemperature.png")

plt.show(sns_plot1)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-12-33cfe6646827> in <module>()
#      25 # Save the image and display
#      26
# ---> 27 sns_plot1.savefig("../Images/Latitude_vs_MaxTemperature.png")
#      28
#      29 plt.show(sns_plot1)
#
# ~\Anaconda3\envs\pythondata\lib\site-packages\seaborn\axisgrid.py in savefig(self, *args, **kwargs)
#      36         kwargs = kwargs.copy()
#      37         kwargs.setdefault("bbox_inches", "tight")
# ---> 38         self.fig.savefig(*args, **kwargs)
#      39
#      40     def add_legend(self, legend_data=None, title=None, label_order=None,
#
# ~\Anaconda3\envs\pythondata\lib\site-packages\matplotlib\figure.py in savefig(self, fname, **kwargs)
#    2033             self.set_frameon(frameon)
#    2034
# -> 2035         self.canvas.print_figure(fname, **kwargs)
#    2036
#    2037         if frameon:
#
# ~\Anaconda3\envs\pythondata\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2261                 orientation=orientation,
#    2262                 bbox_inches_restore=_bbox_inches_restore,
# -> 2263                 **kwargs)
#    2264         finally:
#    2265             if bbox_inches and restore_bbox:
#
# ~\Anaconda3\envs\pythondata\lib\site-packages\matplotlib\backends\backend_agg.py in print_png(self, filename_or_obj, *args, **kwargs)
#     524
#     525         try:
# --> 526             with cbook.open_file_cm(filename_or_obj, "wb") as fh:
#     527                 _png.write_png(renderer._renderer, fh,
#     528                                self.figure.dpi, metadata=metadata)
#
# ~\Anaconda3\envs\pythondata\lib\contextlib.py in __enter__(self)
#      79     def __enter__(self):
#      80         try:
# ---> 81             return next(self.gen)
#      82         except StopIteration:
#      83             raise RuntimeError("generator didn't yield") from None
#
# ~\Anaconda3\envs\pythondata\lib\site-packages\matplotlib\cbook\__init__.py in open_file_cm(path_or_file, mode, encoding)
#     622 def open_file_cm(path_or_file, mode="r", encoding=None):
#     623     r"""Pass through file objects and context-manage `.PathLike`\s."""
# --> 624     fh, opened = to_filehandle(path_or_file, mode, True, encoding)
#     625     if opened:
#     626         with fh:
#
# ~\Anaconda3\envs\pythondata\lib\site-packages\matplotlib\cbook\__init__.py in to_filehandle(fname, flag, return_opened, encoding)
#     607             fh = bz2.BZ2File(fname, flag)
#     608         else:
# --> 609             fh = io.open(fname, flag, encoding=encoding)
#     610         opened = True
#     611     elif hasattr(fname, 'seek'):
#
# FileNotFoundError: [Errno 2] No such file or directory: '../Images/Latitude_vs_MaxTemperature.png'

# %% [markdown]
# Step 7 :
#
# City Latitude vs Humidity -

# %%
# Define the lmplot structure

sns.set()

sns.set_context("notebook")

sns_plot2 = sns.lmplot( x="Latitude", y="Humidity",size=6,data = Weather_Summary_Cities_500_Reindexed,fit_reg=False, 
           hue="Humidity_Category", legend=False, palette=dict(Moist="#0343df",Optimum="#01ff07",Dry="#e50000"))

# Label the plot

Plot_Title = f"City Latitude vs Humidity: {Today_Date}"
plt.title(Plot_Title)

plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

plt.xlim(-80,100)
plt.ylim(-10, 120)

plt.legend(loc='lower left')

# Save the image and display

sns_plot2.savefig("/Images/Latitude_vs_Humidity.png")


plt.show(sns_plot2)

# %% [markdown]
# Step 8 :
#
# City Latitude vs Cloudness (%) -

# %%
# Define the lmplot structure

sns.set()

sns.set_context("notebook")

sns_plot3 = sns.lmplot( x="Latitude", y="Cloudiness",size=6, data = Weather_Summary_Cities_500_Reindexed,fit_reg=False, 
           hue="Cloudiness_Category", legend=False, palette=dict(Clear="#0343df", Partly_Cloudy="#01ff07",Cloudy="#ae7181"))

# Label the plot

Plot_Title = f"City Latitude vs Cloudiness: {Today_Date}"
plt.title(Plot_Title)

plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

plt.xlim(-80,100)
plt.ylim(-10, 120)

plt.legend(loc='upper left')

# Save the image and display

sns_plot3.savefig("\Images\Latitude_vs_Cloudiness.png")

plt.show(sns_plot3)

# %% [markdown]
# Step 9 :
#
# City Latitude vs Wind Speed -

# %%
# Define the scatter plot structure

plt.scatter(Weather_Summary_Cities_500_Reindexed["Latitude"], 
            Weather_Summary_Cities_500_Reindexed["Wind_Speed"],marker="o", facecolors="green", edgecolors="black")

# Label the plot

Plot_Title = f"City Latitude vs Wind_Speed: {Today_Date}"
plt.title(Plot_Title)

plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")

plt.xlim(-80,100)
plt.ylim(-5,40)

# Save the image and display

plt.savefig("/Images/Latitude_vs_WindSpeed.png")

plt.show()

# %%
# Save the comprehensive dataframe to CSV

Weather_Summary_Cities_500_Reindexed.to_csv("\Resources\WeatherData_500Cities.csv", index=False, header=True)

# %% [markdown]
# Step 10:
#
# I use pairplot from searborn library to look at the analysis in one canvas.

# %%
# Define the pairplot structure

sns.set()

sns.set_context("notebook")

sns_plot4 = sns.pairplot(Weather_Summary_Cities_500_Reindexed, size = 4,
             y_vars=["Latitude"],
             x_vars=["Max_Temperature","Humidity","Cloudiness","Wind_Speed"])

# Label the plot

Plot_Title = f"Weather_Analysis_{Today_Date}"

plt.subplots_adjust(top=0.9)

sns_plot4.fig.suptitle(Plot_Title)

sns_plot4.savefig(Plot_Title)

plt.show(sns_plot4)
