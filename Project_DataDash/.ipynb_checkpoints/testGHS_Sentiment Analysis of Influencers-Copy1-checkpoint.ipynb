# %% [markdown]
# # 1. Data Analysis of the Influencers:
# # 2. Sentiment Analysis of the Influencers:

# %%
# Import the Dependencies
import tweepy
import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import time
# import seaborn as sns
from os import path, makedirs # fetch path and makedirs function from os file
import csv # fetch csv file
from glob import glob # fetching glob function only from the glob lib

# %%
# Import keys from the config file
from config import consumer_key, consumer_secret, access_token, access_token_secret

# %%
# # Twitter API Keys
# consumer_key = 'Your Key'
# consumer_secret = 'Your Key'
# access_token = 'Your Key'
# access_token_secret = 'Your Key'

# %%
# Import and Initialize Sentiment Analyzer
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %%
# Setup Tweepy API Authentication
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# %%
# Load and read csv file containing the details of the Influencers 
# influencer_data_read_List = []
influencer_data_load = "RawData/The_Influencers.csv"
influencer_data_read = pd.read_csv(influencer_data_load)
Influencers_DF = influencer_data_read.head(5)
Influencers_DF.keys()
# Out:
# Index(['Twiter_Handle', 'First_Name', 'Last_Name', 'Profession '], dtype='object')

# %%
###
# Influencers = influencer_data_read
# s = Influencers.iloc[:,0]

# %%
# Extract the first 100 tweets of the Influencers
print("-----------Start extraction of the tweets posted by the Influencers!!!-----------")
Influencers = []
Influencers = influencer_data_read
Influencers_th = Influencers.iloc[:,0]
# # Array to hold the sentiments
# Tweet_array = []
Sentiment_array = []

# for user in Influencers[0]:
# for user in Influencers_th:
for user in abridged:
    # Set the tweet count to 100
    tweet_count = 100
    print("Extracting tweets from %s"%user)
    
    # Extract tweets up to 5 pages
    for x in range(1):
        influencer_tweets = api.user_timeline(user,page = 1)
influencer_tweets        
        
#         # For each tweet in a bunch of public tweets
for tweet in influencer_tweets:
            
            #Calculate the compound, positive, negative and neutral values of each tweet
            compound = analyzer.polarity_scores(tweet["text"])["compound"]
            pos = analyzer.polarity_scores(tweet["text"])["pos"]
            neu = analyzer.polarity_scores(tweet["text"])["neu"]
            neg = analyzer.polarity_scores(tweet["text"])["neg"]
            
            # Save the Tweets in an array as a dictionery item 
            Sentiment_array.append({"Influencers" : user,
                                    "Tweet Text" : tweet["text"],
                                    "Compound" : compound,
                                    "Positive" : pos,
                                    "Negative" : neg,
                                    "Neutral" : neu,
                                    "Date" : tweet["created_at"],
                                    "Tweets Ago" : tweet_count
                                   })
            
            #Decrease count of tweet by 1 in the reverse order
            tweet_count -= 1

print("-----------End of Extraction of Tweets !!!-----------")
# Out:
# -----------Start extraction of the tweets posted by the Influencers!!!-----------
# Extracting tweets from @IAMannalynnemcc
# Extracting tweets from @EmmaWatson
# Extracting tweets from @JuliaRoberts
# Extracting tweets from @LeoDiCaprio
# Extracting tweets from @EvaLongoria
# Extracting tweets from @TheRock
# Extracting tweets from @jessicaalba
# Extracting tweets from @PatrcikDempsey
# Extracting tweets from @EllenPompeo
# Extracting tweets from @JessicaCapshaw
# Extracting tweets from @sarahdrew
# Extracting tweets from @IamSandraOh
# Extracting tweets from @SaraRamirez
# Extracting tweets from @iJesseWilliams
# Extracting tweets from @TheRealKMcKidd
# Extracting tweets from @camilluddingtun
# Extracting tweets from @KatieHeigl
# Extracting tweets from @JasonWGeorge
# Extracting tweets from @chy_leigh
# Extracting tweets from @katewalsh
# Extracting tweets from @KellyMcCreary
# Extracting tweets from @IWashington
# Extracting tweets from @DohertyShannen
# Extracting tweets from @shenaegrimes
# Extracting tweets from @JessicaLStroup
# Extracting tweets from @MattLanter
# Extracting tweets from @MACKWILDS
# Extracting tweets from @EmilyVanCamp
# Extracting tweets from @Gabriel_Mann
# Extracting tweets from @Nick_Wechsler
# Extracting tweets from @christabrittany
# Extracting tweets from @smashleybell
# Extracting tweets from @BarrySloane
# Extracting tweets from @MichaelEmerson
# Extracting tweets from @AmyAcker
# Extracting tweets from @sarahshahi
# Extracting tweets from @TherealTaraji
# Extracting tweets from @TaySchilling
# Extracting tweets from @LauraPrepon
# Extracting tweets from @UzoAduba
# Extracting tweets from @nlyonne
# Extracting tweets from @thedanieb
# Extracting tweets from @Lavernecox
# Extracting tweets from @therealleadelaria
# Extracting tweets from @chrisrock
# Extracting tweets from @JerrySeinfield
# Extracting tweets from @therealroseanne
# Extracting tweets from @TheLewisBlack
# Extracting tweets from @MelBrooks
# Extracting tweets from @JimCarrey
# Extracting tweets from @KevinHart4real
# Extracting tweets from @hannibalburess
# Extracting tweets from @StephenAtHome
# Extracting tweets from @billburr
# Extracting tweets from @davidcrosss
# Extracting tweets from @ofctimallen
# Extracting tweets from @JimBreuer
# Extracting tweets from @ericandre
# Extracting tweets from @SandraBernhard
# Extracting tweets from @BillyCrystal
# Extracting tweets from @arjbarker
# Extracting tweets from @RealCarrotTop
# Extracting tweets from @PreacherLawson
# Extracting tweets from @attell
# Extracting tweets from @ElayneBoosler
# Extracting tweets from @Ornyadams
# Extracting tweets from @amyschumer
# Extracting tweets from @SarahKSilverman
# Extracting tweets from @TheEllenShow
# Extracting tweets from @iamwandaskyes
# Extracting tweets from @chelseahandler
# Extracting tweets from @TigNotaro
# Extracting tweets from @mariabamfoo
# Extracting tweets from @margaretcho
# Extracting tweets from @WhoopiGoldberg
# Extracting tweets from @ilanusglazer
# Extracting tweets from @aparnapkin
# Extracting tweets from @LisaLampanelli
# Extracting tweets from @kathygriffin
# Extracting tweets from @cameronesposito
# Extracting tweets from @WhitneyCummings
# Extracting tweets from @iamsambee
# Extracting tweets from @chelseaperetti
# Extracting tweets from @mindykaling
# Extracting tweets from @dopequeenpheebs
# Extracting tweets from @iliza
# Extracting tweets from @aliwong
# Extracting tweets from @msjwilly
# Extracting tweets from @JenKirkman
# Extracting tweets from @taylorswift13
# Extracting tweets from @ArianaGrande
# Extracting tweets from @edsheeran
# Extracting tweets from @BrunoMars
# Extracting tweets from @selenagomez
# Extracting tweets from @katyperry
# Extracting tweets from @carrieunderwood
# Extracting tweets from @KeithUrban
# Extracting tweets from @PaulMcCartney
# Extracting tweets from @ladygaga
# Extracting tweets from @iamDiddy
# Extracting tweets from @bobdylan
# Extracting tweets from @MileyCyrus
# Extracting tweets from @kelly_clarkson
# Extracting tweets from @StevieWonder
# Extracting tweets from @kanyewest
# Extracting tweets from @kendricklamar
# Extracting tweets from @OzzyOsbourne
# Extracting tweets from @WillieNelson
# Extracting tweets from @jtimberlake
# Extracting tweets from @ShawnMendes
# Extracting tweets from @BritneySpears
# Extracting tweets from @LukeBryanOnline
# Extracting tweets from @SantanaCarlos
# Extracting tweets from @jlo
# Extracting tweets from @billieelish
# Extracting tweets from @BebeRexha
# Extracting tweets from @imjmichaels
# Extracting tweets from @CalvinHarris
# Extracting tweets from @DuaLipa
# Extracting tweets from @JessGlynne
# Extracting tweets from @EllaHenderson
# Extracting tweets from @samsmithworld
# Extracting tweets from @TantrumJas
# Extracting tweets from @ParsonJames
# Extracting tweets from @JamesArthur23
# Extracting tweets from @ddlovato
# Extracting tweets from @ollyofficial
# Extracting tweets from @elliegoulding
# Extracting tweets from @IGGYAZALEA
# Extracting tweets from @TinieTempah
# Extracting tweets from @chrisbrown
# Extracting tweets from @justinbeiber
# Extracting tweets from @jasonderulo
# Extracting tweets from @MeekMill
# Extracting tweets from @Jumpman23
# Extracting tweets from @kobebryant
# Extracting tweets from @raylewis
# Extracting tweets from @FloydMayweather
# Extracting tweets from @SHAQ
# Extracting tweets from @larrybirddaily
# Extracting tweets from @RealBillRussell
# Extracting tweets from @tonyparker
# Extracting tweets from @Cristiano
# Extracting tweets from @serenawilliams
# Extracting tweets from @YaoMing
# Extracting tweets from @rogerfederer
# Extracting tweets from @KingJames
# Extracting tweets from @carmeloanthony
# Extracting tweets from @KDTrey5
# Extracting tweets from @alleniverson
# Extracting tweets from @TheNotoriousMMA
# Extracting tweets from @TigerWoods
# Extracting tweets from @OBJ_3
# Extracting tweets from @Kaepernick7
# Extracting tweets from @MariaSharapova
# Extracting tweets from @MiaHamm
# Extracting tweets from @HollyHolm
# Extracting tweets from @Sara_McMann
# Extracting tweets from @Bharper3407
# Extracting tweets from @TheJudge44
# Extracting tweets from @davidortiz
# Extracting tweets from @JeterTurn2
# Extracting tweets from @AROD
# Extracting tweets from @AmericanRaceTNT
# Extracting tweets from @MichaelPhelps
# Extracting tweets from @gabrielledoug
# Extracting tweets from @Simone_Biles
# Extracting tweets from @MichelleWKwan
# Extracting tweets from @WayneGretzky
# Extracting tweets from @MartinBrodeur
# Extracting tweets from @ToreyKrug
# Extracting tweets from @drose
# Extracting tweets from @KyrieIrving
# Extracting tweets from @BenSimmons25
# Extracting tweets from @RobGronkowski
# Extracting tweets from @Venuseswilliams
# Extracting tweets from @AndreAgassi
# Extracting tweets from @OscarDeLaHoya
# Extracting tweets from @Giannis_An34
# Extracting tweets from @TheRock
# Extracting tweets from @kawhileonard
# Extracting tweets from @StephenCurry30
# Extracting tweets from @AntDavis23
# Extracting tweets from @KarlTowns
# Extracting tweets from @JohnWall
# Extracting tweets from @KlayThompson
# Extracting tweets from @WWERomanReigns
# Extracting tweets from @M_Ryan02
# Extracting tweets from @NiaJaxWWE
# Extracting tweets from @titoortiz
# Extracting tweets from @SpiderAnderson
# Extracting tweets from @TyrodTaylor
# Extracting tweets from @tonyromo
# Extracting tweets from @bengreenfield
# Extracting tweets from @lancearmstrong
# Extracting tweets from @tonyhawk
# Extracting tweets from @RyanSheckler
# Extracting tweets from @prod84
# Extracting tweets from @BAM_MARGERA
# Extracting tweets from @TravisPastrana
# Extracting tweets from @derekhough
# Extracting tweets from @juliannehough
# Extracting tweets from @JeffGordonWeb
# Extracting tweets from @JimmyJohnson
# Extracting tweets from @JohnCena
# Extracting tweets from @DanicaPatrick
# Extracting tweets from @nickdiaz209
# Extracting tweets from @DaleJr
# Extracting tweets from @CameronHanes
# Extracting tweets from @shaunwhite
# Extracting tweets from @DjokerNole
# Extracting tweets from @steveaustinBSR
# Extracting tweets from @UKCoachCalipari
# Extracting tweets from @RSherman_25
# Extracting tweets from @CP3
# Extracting tweets from @CaroWozniacki
# Extracting tweets from @RondaRousey
# Extracting tweets from @SkyDigg4
# Extracting tweets from @Candace_Parker
# Extracting tweets from @criscyborg
# Extracting tweets from @Amanda_Leoa
# Extracting tweets from @MieshaTate
# Extracting tweets from @JoelEmbiid
# Extracting tweets from @ApoloOhno
# Extracting tweets from @usainbolt
# Extracting tweets from @blakegriffin23
# Extracting tweets from @kevinlove
# Extracting tweets from @mistyonpointe
# Extracting tweets from @MikeTyson
# Extracting tweets from @GeorgeForeman
# Extracting tweets from @StephMcMahon
# Extracting tweets from @rolopez42
# Extracting tweets from @DwyaneWade
# Extracting tweets from @BizNasty2point0
# Extracting tweets from @gracie_kron
# Extracting tweets from @GarbiMuguruza
# Extracting tweets from @alexmorgan13
# Extracting tweets from @SteveNash
# Extracting tweets from @J_No24
# Extracting tweets from @MSkinner2016
# Extracting tweets from @ShawnJohnson
# Extracting tweets from @kristiyamaguchi
# Extracting tweets from @McIlroyRory
# Extracting tweets from @LewisHamilton
# Extracting tweets from @neymarjr
# Extracting tweets from @RafaelNadal
# Extracting tweets from @GarethBale11
# Extracting tweets from @MoSalah
# Extracting tweets from @keinishikori
# Extracting tweets from @Canelo
# Extracting tweets from @Aly_Raisman
# Extracting tweets from @MikeTrout
# Extracting tweets from @DameLillard
# Extracting tweets from @realDonaldTrump
# Extracting tweets from @HilaryClinton
# Extracting tweets from @BarackObama
# Extracting tweets from @BillClinton
# Extracting tweets from @BernieSanders
# Extracting tweets from @tedcruz
# Extracting tweets from @JohnKasich
# Extracting tweets from @marcorubio
# Extracting tweets from @SecretaryCarson
# Extracting tweets from @JebBush
# Extracting tweets from @gov_gilmore
# Extracting tweets from @GovChristie
# Extracting tweets from @CarlyFiorina
# Extracting tweets from @RickSantorum
# Extracting tweets from @RandPaul
# Extracting tweets from @MartinO'Malley
# Extracting tweets from @GovMikeHuckabee
# Extracting tweets from @GovernorPataki
# Extracting tweets from @LindseyGrahamSC
# Extracting tweets from @BobbyJindal
# Extracting tweets from @lessig
# Extracting tweets from @LincolnChafee
# Extracting tweets from @JimWebbUSA
# Extracting tweets from @ScottWalker
# Extracting tweets from @SecretaryPerry
# Extracting tweets from @JoeBiden
# Extracting tweets from @SenGillibrand
# Extracting tweets from @SenWarren
# Extracting tweets from @CoryBooker
# Extracting tweets from @SenSherrodBrown
# Extracting tweets from @KamalaHarris
# Extracting tweets from @AKWeissman
# Extracting tweets from @lpolgreen
# Extracting tweets from @Schriock1
# Extracting tweets from @ninaturner
# Extracting tweets from @MassAGO
# Extracting tweets from @susanamendoza10
# Extracting tweets from @BrianBallard723
# Extracting tweets from @nick_ayers
# Extracting tweets from @JohnMorganESQ
# Extracting tweets from @SenJohnMcCain
# Extracting tweets from @GeorgeHWBush
# Extracting tweets from @TheBushCenter
# Extracting tweets from @SpeakerRyan
# Extracting tweets from @CarterCenter
# Extracting tweets from @farenthold
# Extracting tweets from @MooreSenate
# Extracting tweets from @MittRomney
# Extracting tweets from @Schwarzenegger
# Extracting tweets from @USAGSessions
# Extracting tweets from @RepJohnConyers
# Extracting tweets from @dickcheney
# Extracting tweets from @GregForMontana
# Extracting tweets from @The_Tim_Murphy
# Extracting tweets from @JohnKerry
# Extracting tweets from @jaredpolis
# Extracting tweets from @PaulManafort
# Extracting tweets from @PressSec
# Extracting tweets from @SarahPalinUSA
# Extracting tweets from @BarneyFrank
# Extracting tweets from @DavidCameron
# Extracting tweets from @VP
# Extracting tweets from @algore
# Extracting tweets from @NancyPelosi
# Extracting tweets from @SenateMajLdr
# Extracting tweets from @SenSchumer
# Extracting tweets from @repjowrowley
# Extracting tweets from @timkaine
# Extracting tweets from @newtgingrich
# Extracting tweets from @GovRauner
# Extracting tweets from @SenatorLeahy
# Extracting tweets from @MarkWarner
# Extracting tweets from @johnrobertsFox
# Extracting tweets from @clairecmc
# Extracting tweets from @senorrinhatch
# Extracting tweets from @SpeakerJeff
# Extracting tweets from @CoryBooker
# Extracting tweets from @mtbarra
# Extracting tweets from @IndraNooyi
# Extracting tweets from @satyanadella
# Extracting tweets from @narendramodi
# Extracting tweets from @arunjaitley
# Extracting tweets from @JustinTrudeau
# Extracting tweets from @EmmanuelMacron
# Extracting tweets from @RT_Erdogan
# Extracting tweets from @EPN
# Extracting tweets from @dilmabr
# Extracting tweets from @MedvedevRussiaE
# Extracting tweets from @IvankaTrump
# Extracting tweets from @JDMahama
# Extracting tweets from @eucopresident
# Extracting tweets from @BarackObama
# Extracting tweets from @BernieSanders
# Extracting tweets from @elizabethforma
# Extracting tweets from @elonmusk
# Extracting tweets from @SadiqKhan
# Extracting tweets from @jeremycorbyn
# Extracting tweets from @theresa_may
# Extracting tweets from @Grybauskaite_LT
# Extracting tweets from @frankmugisha
# Extracting tweets from @JeffBezos
# Extracting tweets from @thomasbuberl
# Extracting tweets from @DeanBaker13
# Extracting tweets from @econjared
# Extracting tweets from @NYTimesKrugman
# Extracting tweets from @MarkThoma
# Extracting tweets from @umairh
# Extracting tweets from @profsufi
# Extracting tweets from @Nouriel
# Extracting tweets from @justinwolfers
# Extracting tweets from @BetseyStevenson
# Extracting tweets from @omzidar
# Extracting tweets from @Noahpinion
# Extracting tweets from @Austan_Goolsbee
# Extracting tweets from @BruceBartlett
# Extracting tweets from @mileskimball
# Extracting tweets from @KingEconomist
# Extracting tweets from @jodiecongirl
# Extracting tweets from @kaushikcbasu
# Extracting tweets from @haroldpollack
# Extracting tweets from @econoflove
# Extracting tweets from @SBronars
# Extracting tweets from @joebrusuelas
# Extracting tweets from @IanShepherdson
# Extracting tweets from @bill_easterly
# Extracting tweets from @AllisonSchrager
# Extracting tweets from @RBReich
# Extracting tweets from @TimDuy
# Extracting tweets from @MsNicoleClark
# Extracting tweets from @kyrstensinema
# Extracting tweets from @RepBarbaraLee
# Extracting tweets from @Relando_T
# Extracting tweets from (@MikeLICSW
# Extracting tweets from @njsmyth
# Extracting tweets from (@socworkpodcast
# Extracting tweets from (@johannagreeson
# Extracting tweets from @JimmySW
# Extracting tweets from @tiziana_dearing
# Extracting tweets from (@ProfessorChic
# Extracting tweets from @chrisremani1 ‏
# Extracting tweets from @looloolollie ‏
# Extracting tweets from @RealKHughes ‏
# Extracting tweets from @LeireAgirre4 ‏
# Extracting tweets from @BeckyEBurden ‏
# Extracting tweets from @JeanneC12467841 ‏
# Extracting tweets from @AndyPorter15 ‏
# Extracting tweets from @hungryghost741 ‏
# Extracting tweets from @SWMichaelGraham ‏
# Extracting tweets from @sfhosali ‏
# Extracting tweets from @DrKumarVishwas
# Extracting tweets from @drjoekort
# Extracting tweets from @BDUTT
# Extracting tweets from @RaggiKotak
# Extracting tweets from @Maria_Moodie ‏
# Extracting tweets from @CarolStorerLAPG ‏
# Extracting tweets from @WendyPettifer ‏
# Extracting tweets from @ChristianKerrSW ‏
# Extracting tweets from @BrendanWhittle ‏
# Extracting tweets from @RossAbramowitz ‏
# Extracting tweets from @oyinlolaolugbe1 ‏
# Extracting tweets from @Martha7144
# Extracting tweets from @Bonesixty ‏
# Extracting tweets from @mmt98 ‏
# Extracting tweets from @ojfolaranmi ‏
# Extracting tweets from @IanCummins9 ‏
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-1eaf1eabff28> in <module>()
#      29
#      30             # Save the Tweets in an array as a dictionery item
# ---> 31             Sentiment_array.append({"Influencers" : user,
#      32                                     "Tweet Text" : tweet["text"],
#      33                                     "Compound" : compound,
#
# NameError: name 'Sentiment_array' is not defined

# %%
# Create dataframe from the Dictionery item of the Sentiment Array
Sentiment_DF = pd.DataFrame.from_dict(Sentiment_array)

# Remove the '@' from the 'influence' column in the data frame
Sentiment_DF["Influencers"] = Sentiment_DF["Influencers"].map(lambda x: x.lstrip('@'))

# Re_arrang the columns and save into a CSV file
Sentiment_DF = Sentiment_DF[["Influencers", "Date", "Tweet Text"
                             , "Compound", "Positive", "Negative"
                             , "Neutral", "Tweets Ago"
                            ]]

# Store output in a .CSV File
Sentiment_DF.to_csv("influencer_tweets_Analysis.csv")

Sentiment_DF
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-da769dcec48a> in <module>()
#       1 # Create dataframe from the Dictionery item of the Sentiment Array
# ----> 2 Sentiment_DF = pd.DataFrame.from_dict(Sentiment_array)
#       3
#       4 # Remove the '@' from the 'influence' column in the data frame
#       5 Sentiment_DF["Influencers"] = Sentiment_DF["Influencers"].map(lambda x: x.lstrip('@'))
#
# NameError: name 'Sentiment_array' is not defined

# %%
# Calculate the mean for each Influencers & store into a dataframe
Influencers_Comp_Mean = Sentiment_DF.groupby("Influencers").mean()["Compound"].to_frame()

#Reset the index 
Influencers_Comp_Mean.reset_index(inplace=True)

Influencers_Comp_Mean
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-fa331fbce4f5> in <module>()
#       1 # Calculate the mean for each Influencers & store into a dataframe
# ----> 2 Influencers_Comp_Mean = Sentiment_DF.groupby("Influencers").mean()["Compound"].to_frame()
#       3
#       4 #Reset the index
#       5 Influencers_Comp_Mean.reset_index(inplace=True)
#
# NameError: name 'Sentiment_DF' is not defined

# %%
# Set the values for x_axis & y_axis
x_axis = Influencers_Comp_Mean.index.values
y_axis = Influencers_Comp_Mean["Compound"]
X_Label = ["@Oprah","@KimKardashian","@realDonaldTrump","@justinbieber","@KylieJenner"]

# Intialize the plots. 
fig,ax = plt.subplots()#  function that returns a tuple containing a figure and axes object(s)

#Set the plot and assign the values like colors etc
bars = ax.bar(x_axis,y_axis
              , align = "edge"
              , width = 1
              , linewidth = 1
              , edgecolor = 'black'
              , color = ["yellow","lime","red","orange","pink"]
             )

# Set the tick(s) of the bar graph
tick_locations = [value + 0.5 for value in range(len(x_axis))]
plt.xticks(tick_locations,X_Label,rotation='vertical')

# If value is positive then put True in the Summary else place False
Influencers_Comp_Mean["Positive"] = Influencers_Comp_Mean["Compound"] > 0

# Assign the height based on positive value after allocating True / false value
height = Influencers_Comp_Mean.Positive.map({True: 0.03 , False: -0.03})

# # Set the value on labels on the bars
for bar in bars:
    ax.text(bar.get_x() + bar.get_width()/2, bar.get_height() + height[bars.index(bar)]
            , round(Influencers_Comp_Mean["Compound"][bars.index(bar)],3)
            , ha = 'center'
            , va = 'bottom'
            )

# Set the x_axis limits
ax.set_xlim(0, len(x_axis))

# Dynamically set the y_axis limits by finding the max & min value of y-axis
ax.set_ylim(min(y_axis)-0.1, max(y_axis) + 0.1)

# Set a horizontal line at y = 0
plt.hlines(0,0,len(x_axis))

# Title of the graph
ax.set_title("Sentiments on Twitter of Influencers (%s)" % (time.strftime("%x")), fontsize=16)

# Setting the y_axis label
ax.set_ylabel("Polarity on Twitter ", fontsize=14)

# # Setting the x_axis label
ax.set_xlabel("The Influencers", fontsize=14)
  
# Saving the graph
plt.savefig("The Influencer Twitter Sentiment .png",bbox_inches='tight')
plt.show()

# %%
# Create an array of Influencers Houses with the unique function in the data frame
Influencers_array = Sentiment_DF["Influencers"].unique()
Influencers_array

# # #Plotting the graph for each influencer
# for influencer in Influencers_array:
# # Creating a temporary data frame to store for only one influencer at a time
#         Temp_DF = Sentiment_DF[Sentiment_DF["influencer"] == influencer]
        
#         Sentiment_DF['influencer'] = Sentiment_DF['influencer'].map(lambda x: x.lstrip('@'))
# #Temp_DF
    
#         plt.scatter(Temp_DF["Tweets Ago"],Temp_DF["Compound"]
#                  , marker = "o", linewidth = 0, alpha = 0.8, label = Influencers
#                  , facecolors = Temp_DF.influencer.map({"@Oprah": "blue"
#                                                    , "@KimKardashian" : "lime"
#                                                    , "@realDonaldTrump": 'indigo'
#                                                    , "@justinbieber":"fuchsia"
#                                                    , "@KylieJenner":"gold"
#                                                   })
#                 )

# # # Set the legend 
# plt.legend(bbox_to_anchor = (1,1), title="The Influencers", loc='best')

# # # Set the labels of x_axis, y_axis & title 
# plt.xlabel("Tweets Ago", fontsize=12)
# plt.ylabel("Tweet Polarity", fontsize=12)
# plt.title("Sentiment Analysis of The Influencers Tweets (%s)" % (time.strftime("%x")), fontsize=16)

# # #Set the limite of  x_axis and y_axis
# plt.xlim(0, 101)
# plt.ylim(-1,1)

# # # Set the grid
# plt.grid(True)

# filePath = 'Images'
# if not path.exists(filePath):
#     makedirs(filePath)

# # Save the result to a .png file
# plt.savefig("Sentiment Analysis of Influencers Tweets.png",bbox_inches='tight')
# # plt.savefig("Sentiment Analysis of The influencer's Tweets.png",bbox_inches='tight')

# plt.show()
